# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from numpy.linalg import inv

# %%
def calculate_Beta(lamda,x,y,i):
  M = np.identity(i)

  mlamda = lamda * M
 
  x_trans = pd.DataFrame(np.transpose(x))
  
  intermediate = pd.DataFrame(np.dot(x_trans,x))
  
  add = pd.DataFrame(intermediate + mlamda)
  
  inverse = inv(np.matrix(add))
  
  dotproduct = pd.DataFrame(np.dot(x_trans, y))
  
  beta = pd.DataFrame(np.dot(inverse,dotproduct))
  
  return beta

# %%
def calculate_ycap(x, beta):
  
  #beta = calculate_Beta(x)

  ycap = pd.DataFrame(np.dot(x,beta))
 
  return ycap

# %%
def calculate_MAE(x, y, ycap):
  
  sum = 0
  
  for i in range(len(x)):
    
    y_i = y.iloc[i]
    
    y_i_cap = ycap.iloc[i]
    
    difference = abs(y_i_cap - y_i)
    
    sum += difference
    
  return (sum/len(x))

# %%
def calculate_RMSE(x, y, ycap):
  sum = 0
  for i in range(len(x)):
    y_i = y.iloc[i]
    y_i_cap = ycap.iloc[i]
    squared = (y_i_cap - y_i) **2
    sum += squared
  avg = sum/len(x)
  return (math.sqrt(avg))

# %%
lamda=[0, 0.000000005, 0.0000015, 0.0002, 1, 2]
for l in lamda:
  MAE = []
  RMSE = []
  data_source = '/content/drive/My Drive/Colab Notebooks/FCV/Model 1/'

  for val in range(1,11):
    training_data = pd.read_csv(data_source + 'train' +str(val) + '.csv')
    training_y = training_data.iloc[:,-1]
    training_x = training_data.iloc[:,0:-1]

    testing_data = pd.read_csv(data_source + 'test' +str(val) + '.csv')
    testing_y = testing_data.iloc[:,-1]
    testing_x = testing_data.iloc[:,0:-1]

    beta = calculate_Beta(l,training_x, training_y, 12)
    y_predict = calculate_ycap(training_x, beta)

    MAE_val = calculate_MAE(testing_x, testing_y, y_predict)

    MAE.append(MAE_val)

    RMSE_val = calculate_RMSE(testing_x, testing_y, y_predict)

    RMSE.append(RMSE_val)


  MAE_mean = np.mean(MAE)
  MAE_sd = np.std(MAE)

  RMSE_mean = np.mean(RMSE)
  RMSE_sd = np.std(RMSE)

  print("\n")
  print("For Model 1, at lambda="+str(l))
  print("Mean of MAE is %f" % MAE_mean)
  print("SD of MAE is %f" % MAE_sd)
  print("Mean of RMSE is %f" % RMSE_mean)
  print("SD of RMSE is %f" % RMSE_sd)
# Out:
# For Model 1, at lambda=0
# Mean of MAE is 19.762525
# SD of MAE is 6.961123
# Mean of RMSE is 47.487947
# SD of RMSE is 42.974352
#
#
# For Model 1, at lambda=5e-09
# Mean of MAE is 19.762599
# SD of MAE is 6.961174
# Mean of RMSE is 47.487939
# SD of RMSE is 42.974371
#
#
# For Model 1, at lambda=1.5e-06
# Mean of MAE is 19.774728
# SD of MAE is 6.971343
# Mean of RMSE is 47.483366
# SD of RMSE is 42.979216
#
#
# For Model 1, at lambda=0.0002
# Mean of MAE is 19.729647
# SD of MAE is 7.008812
# Mean of RMSE is 47.374995
# SD of RMSE is 43.032005
#
#
# For Model 1, at lambda=1
# Mean of MAE is 19.018642
# SD of MAE is 7.054703
# Mean of RMSE is 46.600342
# SD of RMSE is 43.401439
#
#
# For Model 1, at lambda=2
# Mean of MAE is 18.958340
# SD of MAE is 7.094375
# Mean of RMSE is 46.543179
# SD of RMSE is 43.445119

# %%
lamda=[0, 0.000000005, 0.0000015, 0.0002, 1, 2]
for l in lamda:
  MAE = []
  RMSE = []
  data_source = '/content/drive/My Drive/Colab Notebooks/FCV/Model 2/'

  for val in range(1,11):
    training_data = pd.read_csv(data_source + 'train' +str(val) + '.csv')
    training_y = training_data.iloc[:,-1]
    training_x = training_data.iloc[:,0:-1]

    testing_data = pd.read_csv(data_source + 'test' +str(val) + '.csv')
    testing_y = testing_data.iloc[:,-1]
    testing_x = testing_data.iloc[:,0:-1]

    beta = calculate_Beta(l, training_x, training_y, 13)
    y_predict = calculate_ycap(training_x, beta)

    MAE_val = calculate_MAE(testing_x, testing_y, y_predict)

    MAE.append(MAE_val)

    RMSE_val = calculate_RMSE(testing_x, testing_y, y_predict)

    RMSE.append(RMSE_val)


  MAE_mean = np.mean(MAE)
  MAE_sd = np.std(MAE)

  RMSE_mean = np.mean(RMSE)
  RMSE_sd = np.std(RMSE)

  print("\n")
  print("For Model 2, at lambda="+str(l))
  print("Mean of MAE is %f" % MAE_mean)
  print("SD of MAE is %f" % MAE_sd)
  print("Mean of RMSE is %f" % RMSE_mean)
  print("SD of RMSE is %f" % RMSE_sd)
# Out:
# For Model 2, at lambda=0
# Mean of MAE is 20.022290
# SD of MAE is 6.818421
# Mean of RMSE is 48.315098
# SD of RMSE is 42.297549
#
#
# For Model 2, at lambda=5e-09
# Mean of MAE is 20.021448
# SD of MAE is 6.818636
# Mean of RMSE is 48.314469
# SD of RMSE is 42.297732
#
#
# For Model 2, at lambda=1.5e-06
# Mean of MAE is 19.923227
# SD of MAE is 6.834363
# Mean of RMSE is 48.233155
# SD of RMSE is 42.320403
#
#
# For Model 2, at lambda=0.0002
# Mean of MAE is 19.777854
# SD of MAE is 6.879216
# Mean of RMSE is 48.052159
# SD of RMSE is 42.414207
#
#
# For Model 2, at lambda=1
# Mean of MAE is 18.953669
# SD of MAE is 7.157419
# Mean of RMSE is 46.756561
# SD of RMSE is 43.298906
#
#
# For Model 2, at lambda=2
# Mean of MAE is 18.892314
# SD of MAE is 7.175796
# Mean of RMSE is 46.672675
# SD of RMSE is 43.352815

# %%
lamda=[0, 0.000000005, 0.0000015, 0.0002, 1, 2]
for l in lamda:
  MAE = []
  RMSE = []
  data_source = '/content/drive/My Drive/Colab Notebooks/FCV/Model 4/'

  for val in range(1,11):
    training_data = pd.read_csv(data_source + 'train' +str(val) + '.csv')
    training_y = training_data.iloc[:,-1]
    training_x = training_data.iloc[:,0:-1]

    testing_data = pd.read_csv(data_source + 'test' +str(val) + '.csv')
    testing_y = testing_data.iloc[:,-1]
    testing_x = testing_data.iloc[:,0:-1]

    beta = calculate_Beta(l, training_x, training_y, 13)
    y_predict = calculate_ycap(training_x, beta)

    MAE_val = calculate_MAE(testing_x, testing_y, y_predict)

    MAE.append(MAE_val)

    RMSE_val = calculate_RMSE(testing_x, testing_y, y_predict)

    RMSE.append(RMSE_val)


  MAE_mean = np.mean(MAE)
  MAE_sd = np.std(MAE)

  RMSE_mean = np.mean(RMSE)
  RMSE_sd = np.std(RMSE)


  print("\n")
  print("For Model 4, at lambda="+str(l))
  print("Mean of MAE is %f" % MAE_mean)
  print("SD of MAE is %f" % MAE_sd)
  print("Mean of RMSE is %f" % RMSE_mean)
  print("SD of RMSE is %f" % RMSE_sd)
# Out:
# For Model 4, at lambda=0
# Mean of MAE is 18.626953
# SD of MAE is 7.291681
# Mean of RMSE is 46.135093
# SD of RMSE is 43.761728
#
#
# For Model 4, at lambda=5e-09
# Mean of MAE is 18.630512
# SD of MAE is 7.276839
# Mean of RMSE is 46.135018
# SD of RMSE is 43.764778
#
#
# For Model 4, at lambda=1.5e-06
# Mean of MAE is 18.638159
# SD of MAE is 7.298186
# Mean of RMSE is 46.132922
# SD of RMSE is 43.770705
#
#
# For Model 4, at lambda=0.0002
# Mean of MAE is 18.607999
# SD of MAE is 7.281124
# Mean of RMSE is 46.139118
# SD of RMSE is 43.765090
#
#
# For Model 4, at lambda=1
# Mean of MAE is 18.581788
# SD of MAE is 7.276834
# Mean of RMSE is 46.133303
# SD of RMSE is 43.773191
#
#
# For Model 4, at lambda=2
# Mean of MAE is 18.559311
# SD of MAE is 7.282583
# Mean of RMSE is 46.124274
# SD of RMSE is 43.782176

# %%
lamda=[0, 0.000000005, 0.0000015, 0.0002, 1, 2]
for l in lamda:
  MAE = []
  RMSE = []
  data_source = '/content/drive/My Drive/Colab Notebooks/FCV/Model 6/'

  for val in range(1,11):
    training_data = pd.read_csv(data_source + 'train' +str(val) + '.csv')
    training_y = training_data.iloc[:,-1]
    training_x = training_data.iloc[:,0:-1]

    testing_data = pd.read_csv(data_source + 'test' +str(val) + '.csv')
    testing_y = testing_data.iloc[:,-1]
    testing_x = testing_data.iloc[:,0:-1]

    beta = calculate_Beta(l, training_x, training_y, 13)
    y_predict = calculate_ycap(training_x, beta)

    MAE_val = calculate_MAE(testing_x, testing_y, y_predict)

    MAE.append(MAE_val)

    RMSE_val = calculate_RMSE(testing_x, testing_y, y_predict)

    RMSE.append(RMSE_val)


  MAE_mean = np.mean(MAE)
  MAE_sd = np.std(MAE)

  RMSE_mean = np.mean(RMSE)
  RMSE_sd = np.std(RMSE)


  print("\n")
  print("For Model 6, at lambda="+str(l))
  print("Mean of MAE is %f" % MAE_mean)
  print("SD of MAE is %f" % MAE_sd)
  print("Mean of RMSE is %f" % RMSE_mean)
  print("SD of RMSE is %f" % RMSE_sd)
# Out:
# For Model 6, at lambda=0
# Mean of MAE is 19.033855
# SD of MAE is 7.163970
# Mean of RMSE is 46.640325
# SD of RMSE is 43.493105
#
#
# For Model 6, at lambda=5e-09
# Mean of MAE is 19.022968
# SD of MAE is 7.165968
# Mean of RMSE is 46.636117
# SD of RMSE is 43.496535
#
#
# For Model 6, at lambda=1.5e-06
# Mean of MAE is 18.928604
# SD of MAE is 7.167680
# Mean of RMSE is 46.554631
# SD of RMSE is 43.530864
#
#
# For Model 6, at lambda=0.0002
# Mean of MAE is 18.744812
# SD of MAE is 7.160976
# Mean of RMSE is 46.370158
# SD of RMSE is 43.620546
#
#
# For Model 6, at lambda=1
# Mean of MAE is 18.461917
# SD of MAE is 7.243300
# Mean of RMSE is 46.123576
# SD of RMSE is 43.754262
#
#
# For Model 6, at lambda=2
# Mean of MAE is 18.436389
# SD of MAE is 7.247315
# Mean of RMSE is 46.110184
# SD of RMSE is 43.766887

# %%
lamda=[0, 0.000000005, 0.0000015, 0.0002, 1, 2]
for l in lamda:
  MAE = []
  RMSE = []
  data_source = '/content/drive/My Drive/Colab Notebooks/FCV/Model 5/'

  for val in range(1,11):
    training_data = pd.read_csv(data_source + 'train' +str(val) + '.csv')
    training_y = training_data.iloc[:,-1]
    training_x = training_data.iloc[:,0:-1]

    testing_data = pd.read_csv(data_source + 'test' +str(val) + '.csv')
    testing_y = testing_data.iloc[:,-1]
    testing_x = testing_data.iloc[:,0:-1]

    beta = calculate_Beta(l, training_x, training_y, 13)
    y_predict = calculate_ycap(training_x, beta)

    MAE_val = calculate_MAE(testing_x, testing_y, y_predict)

    MAE.append(MAE_val)

    RMSE_val = calculate_RMSE(testing_x, testing_y, y_predict)

    RMSE.append(RMSE_val)


  MAE_mean = np.mean(MAE)
  MAE_sd = np.std(MAE)

  RMSE_mean = np.mean(RMSE)
  RMSE_sd = np.std(RMSE)

  print("\n")
  print("For Model 5, at lambda="+str(l))
  print("Mean of MAE is %f" % MAE_mean)
  print("SD of MAE is %f" % MAE_sd)
  print("Mean of RMSE is %f" % RMSE_mean)
  print("SD of RMSE is %f" % RMSE_sd)
# Out:
# For Model 5, at lambda=0
# Mean of MAE is 18.742196
# SD of MAE is 7.383863
# Mean of RMSE is 46.190862
# SD of RMSE is 43.761059
#
#
# For Model 5, at lambda=5e-09
# Mean of MAE is 18.642644
# SD of MAE is 7.338803
# Mean of RMSE is 46.136709
# SD of RMSE is 43.786021
#
#
# For Model 5, at lambda=1.5e-06
# Mean of MAE is 18.639892
# SD of MAE is 7.334516
# Mean of RMSE is 46.138087
# SD of RMSE is 43.785934
#
#
# For Model 5, at lambda=0.0002
# Mean of MAE is 18.611891
# SD of MAE is 7.339563
# Mean of RMSE is 46.130958
# SD of RMSE is 43.793172
#
#
# For Model 5, at lambda=1
# Mean of MAE is 18.589800
# SD of MAE is 7.343322
# Mean of RMSE is 46.124704
# SD of RMSE is 43.799290
#
#
# For Model 5, at lambda=2
# Mean of MAE is 18.570150
# SD of MAE is 7.346677
# Mean of RMSE is 46.119053
# SD of RMSE is 43.804799
